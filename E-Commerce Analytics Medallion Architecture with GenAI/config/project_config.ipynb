# %%
# Databricks notebook source
# PROJECT CONFIGURATION

# Database names
BRONZE_DB = "ecommerce_bronze"
SILVER_DB = "ecommerce_silver"
GOLD_DB = "ecommerce_gold"

# File paths
BASE_PATH = "/Volumes/workspace/default/ecommerce_project_volume"
RAW_DATA_PATH = f"{BASE_PATH}/raw"
BRONZE_PATH = f"{BASE_PATH}/bronze"
SILVER_PATH = f"{BASE_PATH}/silver"
GOLD_PATH = f"{BASE_PATH}/gold"
ML_PATH = f"{BASE_PATH}/ml"

# Table names
BRONZE_TRANSACTIONS_TABLE = f"{BRONZE_DB}.transactions"
BRONZE_PRODUCTS_TABLE = f"{BRONZE_DB}.products"
BRONZE_CUSTOMERS_TABLE = f"{BRONZE_DB}.customers"
BRONZE_RATINGS_TABLE = f"{BRONZE_DB}.ratings"
SILVER_TRANSACTIONS_TABLE = f"{SILVER_DB}.transactions_cleaned"
SILVER_PRODUCTS_TABLE = f"{SILVER_DB}.products_enriched"
SILVER_CUSTOMERS_TABLE = f"{SILVER_DB}.customers_enhanced"
GOLD_FACT_TRANSACTIONS_TABLE = f"{GOLD_DB}.fact_transactions"
GOLD_DIM_PRODUCTS_TABLE = f"{GOLD_DB}.dim_products"
GOLD_DIM_CUSTOMERS_TABLE = f"{GOLD_DB}.dim_customers"
GOLD_DIM_DATE_TABLE = f"{GOLD_DB}.dim_date"

# ML settings
TRAIN_TEST_SPLIT = 0.8
RANDOM_SEED = 42
ALS_MAX_ITER = 10
ALS_REG_PARAM = 0.1
ALS_RANK = 10
print("■ Configuration loaded")
